# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
df1=pd.read_csv('openpowerlifting.csv')
df1
# Out:
#         MeetID              Name Sex   Equipment   Age     Division  \
# 0            0  Angie Belk Terry   F       Wraps  47.0    Mst 45-49
# 1            0       Dawn Bogart   F  Single-ply  42.0    Mst 40-44
# 2            0       Dawn Bogart   F  Single-ply  42.0  Open Senior
# 3            0       Dawn Bogart   F         Raw  42.0  Open Senior
# 4            0      Destiny Dula   F         Raw  18.0   Teen 18-19
# ...        ...               ...  ..         ...   ...          ...
# 360857    8136     Ruben Ramirez   M       Wraps  22.0     Jr 20-23
# 360858    8136    Cameron Decker   M       Wraps  22.0     Jr 20-23
# 360859    8136      Clayton Laws   M       Wraps  23.0     Jr 20-23
# 360860    8136     Matt Scroggin   M       Wraps  23.0     Jr 20-23
# 360861    8136    Eric Radcliffe   M       Wraps  22.0          NaN
#
#         BodyweightKg WeightClassKg  Squat4Kg  BestSquatKg  Bench4Kg  \
# 0              59.60            60       NaN        47.63       NaN
# 1              58.51            60       NaN       142.88       NaN
# 2              58.51            60       NaN       142.88       NaN
# 3              58.51            60       NaN          NaN       NaN
# 4              63.68          67.5       NaN          NaN       NaN
# ...              ...           ...       ...          ...       ...
# 360857         89.50            90       NaN       275.00       NaN
# 360858         99.30           100       NaN       280.00       NaN
# 360859         98.50           100       NaN       245.00       NaN
# 360860        107.00           110       NaN       305.00       NaN
# 360861           NaN           NaN       NaN          NaN       NaN
#
#         BestBenchKg  Deadlift4Kg  BestDeadliftKg  TotalKg Place   Wilks
# 0             20.41          NaN           70.31   138.35     1  155.05
# 1             95.25          NaN          163.29   401.42     1  456.38
# 2             95.25          NaN          163.29   401.42     1  456.38
# 3             95.25          NaN             NaN    95.25     1  108.29
# 4             31.75          NaN           90.72   122.47     1  130.47
# ...             ...          ...             ...      ...   ...     ...
# 360857       142.50          NaN         -275.00      NaN    DQ     NaN
# 360858       167.50          NaN          272.50   720.00     1  439.43
# 360859       150.00          NaN          282.50   677.50     2  414.86
# 360860       175.00          NaN          300.00   780.00     1  463.10
# 360861          NaN          NaN             NaN      NaN   NaN     NaN
#
# [360862 rows x 17 columns]

# %%
df2=pd.read_csv("airbnb.csv")
df2
# Out:
#              id                                              name    host_id  \
# 0          2539                Clean & quiet apt home by the park       2787
# 1          2595                             Skylit Midtown Castle       2845
# 2          3647               THE VILLAGE OF HARLEM....NEW YORK !       4632
# 3          3831                   Cozy Entire Floor of Brownstone       4869
# 4          5022  Entire Apt: Spacious Studio/Loft by central park       7192
# ...         ...                                               ...        ...
# 36329  28910899  Private room in large, central Nolita penthouse!  153154549
# 36330  28910978                        Artistic house with murals   52044518
# 36331  28911697                                  Cozy Artist Room   70230403
# 36332  28911775       LUXURY PRIVATE BEDROOM & Bath Mins from JFK  217621677
# 36333  28911830                     Charming redbrick Bronx Villa      19108
#
#          host_name neighbourhood_group  neighbourhood  latitude  longitude  \
# 0             John            Brooklyn     Kensington  40.64749  -73.97237
# 1         Jennifer           Manhattan        Midtown  40.75362  -73.98377
# 2        Elisabeth           Manhattan         Harlem  40.80902  -73.94190
# 3      LisaRoxanne            Brooklyn   Clinton Hill  40.68514  -73.95976
# 4            Laura           Manhattan    East Harlem  40.79851  -73.94399
# ...            ...                 ...            ...       ...        ...
# 36329        Sarah           Manhattan         Nolita  40.72135  -73.99426
# 36330     Veronica              Queens  East Elmhurst  40.76173  -73.87417
# 36331        Sonya            Brooklyn       Bushwick  40.69677  -73.92688
# 36332       Joseph              Queens     St. Albans  40.68754  -73.77488
# 36333          NaN                 NaN            NaN       NaN        NaN
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 0         Private room  149.0             1.0                9.0  2018-10-19
# 1      Entire home/apt  225.0             1.0               45.0  2019-05-21
# 2         Private room  150.0             3.0                0.0         NaN
# 3      Entire home/apt   89.0             1.0              270.0  2019-07-05
# 4      Entire home/apt   80.0            10.0                9.0  2018-11-19
# ...                ...    ...             ...                ...         ...
# 36329     Private room  140.0             3.0                2.0  2018-10-15
# 36330     Private room   65.0             1.0               58.0  2019-07-08
# 36331     Private room   57.0             1.0                1.0  2018-10-22
# 36332     Private room   50.0             1.0               16.0  2019-07-07
# 36333              NaN    NaN             NaN                NaN         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 0                   0.21                             6.0             365.0
# 1                   0.38                             2.0             355.0
# 2                    NaN                             1.0             365.0
# 3                   4.64                             1.0             194.0
# 4                   0.10                             1.0               0.0
# ...                  ...                             ...               ...
# 36329               0.22                             1.0               0.0
# 36330               6.19                             1.0              47.0
# 36331               0.12                             1.0               0.0
# 36332               1.78                             4.0             137.0
# 36333                NaN                             NaN               NaN
#
# [36334 rows x 16 columns]

# %%
df3 = pd.concat([df1, df2], axis=1)
df3
# Out:
#         MeetID              Name Sex   Equipment   Age     Division  \
# 0            0  Angie Belk Terry   F       Wraps  47.0    Mst 45-49
# 1            0       Dawn Bogart   F  Single-ply  42.0    Mst 40-44
# 2            0       Dawn Bogart   F  Single-ply  42.0  Open Senior
# 3            0       Dawn Bogart   F         Raw  42.0  Open Senior
# 4            0      Destiny Dula   F         Raw  18.0   Teen 18-19
# ...        ...               ...  ..         ...   ...          ...
# 360857    8136     Ruben Ramirez   M       Wraps  22.0     Jr 20-23
# 360858    8136    Cameron Decker   M       Wraps  22.0     Jr 20-23
# 360859    8136      Clayton Laws   M       Wraps  23.0     Jr 20-23
# 360860    8136     Matt Scroggin   M       Wraps  23.0     Jr 20-23
# 360861    8136    Eric Radcliffe   M       Wraps  22.0          NaN
#
#         BodyweightKg WeightClassKg  Squat4Kg  BestSquatKg  ...  latitude  \
# 0              59.60            60       NaN        47.63  ...  40.64749
# 1              58.51            60       NaN       142.88  ...  40.75362
# 2              58.51            60       NaN       142.88  ...  40.80902
# 3              58.51            60       NaN          NaN  ...  40.68514
# 4              63.68          67.5       NaN          NaN  ...  40.79851
# ...              ...           ...       ...          ...  ...       ...
# 360857         89.50            90       NaN       275.00  ...       NaN
# 360858         99.30           100       NaN       280.00  ...       NaN
# 360859         98.50           100       NaN       245.00  ...       NaN
# 360860        107.00           110       NaN       305.00  ...       NaN
# 360861           NaN           NaN       NaN          NaN  ...       NaN
#
#         longitude        room_type  price  minimum_nights number_of_reviews  \
# 0       -73.97237     Private room  149.0             1.0               9.0
# 1       -73.98377  Entire home/apt  225.0             1.0              45.0
# 2       -73.94190     Private room  150.0             3.0               0.0
# 3       -73.95976  Entire home/apt   89.0             1.0             270.0
# 4       -73.94399  Entire home/apt   80.0            10.0               9.0
# ...           ...              ...    ...             ...               ...
# 360857        NaN              NaN    NaN             NaN               NaN
# 360858        NaN              NaN    NaN             NaN               NaN
# 360859        NaN              NaN    NaN             NaN               NaN
# 360860        NaN              NaN    NaN             NaN               NaN
# 360861        NaN              NaN    NaN             NaN               NaN
#
#         last_review  reviews_per_month calculated_host_listings_count  \
# 0        2018-10-19               0.21                            6.0
# 1        2019-05-21               0.38                            2.0
# 2               NaN                NaN                            1.0
# 3        2019-07-05               4.64                            1.0
# 4        2018-11-19               0.10                            1.0
# ...             ...                ...                            ...
# 360857          NaN                NaN                            NaN
# 360858          NaN                NaN                            NaN
# 360859          NaN                NaN                            NaN
# 360860          NaN                NaN                            NaN
# 360861          NaN                NaN                            NaN
#
#         availability_365
# 0                  365.0
# 1                  355.0
# 2                  365.0
# 3                  194.0
# 4                    0.0
# ...                  ...
# 360857               NaN
# 360858               NaN
# 360859               NaN
# 360860               NaN
# 360861               NaN
#
# [360862 rows x 33 columns]
